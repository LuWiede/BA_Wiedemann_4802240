# %%
from transformers import AutoTokenizer, AutoModel, utils, BertTokenizer, pipeline, BertModel
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = "bert-base-uncased" 
input_text = "327[MASK]120"  
input_text1 = "178[MASK]58"
input_text2 = "574[MASK]530"
input_text3 = "643[MASK]120"
input_text4 = "327[MASK]120"

model = BertModel.from_pretrained("bert-base-uncased", output_attentions=True)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

inputs = tokenizer.encode(input_text1, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings

head_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-27de05e551d9432dba60e3bef0b38026" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
from transformers import AutoTokenizer, AutoModel, utils, BertTokenizer, pipeline, BertModel
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = "tbs17/MathBERT" 
input_text = "327[MASK]120"
input_text1 = "178[MASK]58"
input_text2 = "574[MASK]530"
input_text3 = "643[MASK]120"
input_text4 = "327[MASK]120"

model = BertModel.from_pretrained("tbs17/MathBERT", output_attentions=True)
tokenizer = BertTokenizer.from_pretrained('tbs17/MathBERT')

inputs = tokenizer.encode(input_text2, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings

head_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-303a786952e7433db8bcb73d7d4eb48d" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>

# %%
from transformers import AutoTokenizer, AutoModel, utils, BertTokenizer, pipeline, BertModel
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

model_name = "AnReu/math_pretrained_bert" 
input_text = "327[MASK]120"
input_text1 = "178[MASK]58"
input_text2 = "574[MASK]530"
input_text3 = "643[MASK]120"
input_text4 = "327[MASK]120"

model = BertModel.from_pretrained("AnReu/math_pretrained_bert", output_attentions=True)
tokenizer = BertTokenizer.from_pretrained('AnReu/math_pretrained_bert')

inputs = tokenizer.encode(input_text1, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings

head_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-7bf0e0e5e0bb4436be5c4c592f910480" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
