# %%
from transformers import AutoTokenizer, AutoModel, utils, BertTokenizer, pipeline, BertModel
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

from transformers import AutoTokenizer, AutoModel, utils, BertTokenizer, pipeline, BertModel
from bertviz import model_view, head_view
utils.logging.set_verbosity_error()  # Suppress standard warnings

#positive Vorzeichen EQ
model_name = "tbs17/MathBERT" 
input_text = "\\boxed{506}[MASK]506"  
input_text1 = "\\boxed{371}[MASK]371"
input_text2 = "\\boxed{130}[MASK]130"
input_text6 = "\\boxed{43}[MASK]43"

# negative Vorzeichen EQ
input_text3 = "\\boxed{-378}[MASK]-378"
input_text4 = "\\boxed{-371}[MASK]-371"
input_text5 = "\\boxed{-130}[MASK]-130"

model = BertModel.from_pretrained("tbs17/MathBERT", output_attentions=True)
tokenizer = BertTokenizer.from_pretrained('tbs17/MathBERT')

inputs = tokenizer.encode(input_text3, return_tensors='pt')  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings

head_view(attention, tokens)  # Display model view
# Out:
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-711af7929d104313ab1a8ff37b7b36c7" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
